# %%
# Import the dependencies

import pandas as pd
import matplotlib as plt
import numpy as np

# %%
# Create a set of random latitudes and longitude combinations

lats = np.random.uniform(-90.000, 90.000, size = 1500)
lngs = np.random.uniform(-180.000, 180.000, size = 1500)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and lngitude to a list.

coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude

from citipy import citipy

# %%
# Use the print() function to display the latitude and longitude combinations

for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# flinders au
# ostrovnoy ru
# maumere id
# airai pw
# rawah iq
# taolanaro mg
# bur gabo so
# kodiak us
# karratha au
# halifax ca
# khandyga ru
# punto fijo ve
# sorvag fo
# rikitea pf
# tuktoyaktuk ca
# namibe ao
# meulaboh id
# busselton au
# cape town za
# marcona pe
# morehead pg
# bengkulu id
# taolanaro mg
# qaanaaq gl
# balkhash kz
# taolanaro mg
# saint george bm
# albany au
# mataura pf
# hobart au
# souris ca
# waipawa nz
# karaul ru
# ushuaia ar
# provideniya ru
# victoria sc
# tiksi ru
# sofiysk ru
# grimshaw ca
# samusu ws
# clyde river ca
# praia da vitoria pt
# ponta do sol pt
# lai td
# hilo us
# weligama lk
# rikitea pf
# albany au
# nikolskoye ru
# port alfred za
# avarua ck
# georgetown sh
# luangwa zm
# chokurdakh ru
# tasiilaq gl
# mahebourg mu
# luganville vu
# isangel vu
# hithadhoo mv
# mataura pf
# sisimiut gl
# teahupoo pf
# balozi lv
# busselton au
# bur gabo so
# carnarvon au
# dikson ru
# meulaboh id
# rikitea pf
# barentsburg sj
# san patricio mx
# san quintin mx
# rikitea pf
# killybegs ie
# tautira pf
# ponta do sol cv
# igarapava br
# turukhansk ru
# vao nc
# khatanga ru
# henties bay na
# banff gb
# barrow us
# taolanaro mg
# castro cl
# iqaluit ca
# hithadhoo mv
# rikitea pf
# samalaeulu ws
# punta arenas cl
# bethel us
# peleduy ru
# sale au
# thompson ca
# kaohsiung tw
# mataura pf
# mar del plata ar
# kapaa us
# wad madani sd
# mount isa au
# punta arenas cl
# lavrentiya ru
# southbridge nz
# vangaindrano mg
# komsomolskiy ru
# thompson ca
# hilo us
# kapaa us
# punta arenas cl
# chuy uy
# punta arenas cl
# mataura pf
# hermanus za
# vaitupu wf
# raudeberg no
# alta floresta br
# bath us
# atar mr
# bengkulu id
# esso ru
# rikitea pf
# toropets ru
# praia da vitoria pt
# grass valley us
# ayan ru
# taolanaro mg
# punta arenas cl
# castro cl
# albany au
# taolanaro mg
# kiunga pg
# ushuaia ar
# nuuk gl
# ewo cg
# gayny ru
# illoqqortoormiut gl
# castro cl
# rikitea pf
# taolanaro mg
# lorengau pg
# san vicente ph
# fairbanks us
# husavik is
# kargasok ru
# isangel vu
# axim gh
# yerbogachen ru
# nikolskoye ru
# mataura pf
# las choapas mx
# ushuaia ar
# mataura pf
# taolanaro mg
# homer us
# veraval in
# barrow us
# faya td
# busselton au
# ushuaia ar
# norman wells ca
# arraial do cabo br
# qaanaaq gl
# hasaki jp
# coahuayana mx
# hobart au
# butaritari ki
# tuy hoa vn
# la ronge ca
# nikolskoye ru
# umba ru
# lompoc us
# blatnica ba
# nikolskoye ru
# upernavik gl
# fortuna us
# marathon ca
# cherskiy ru
# igarka ru
# busselton au
# punta arenas cl
# hobart au
# busselton au
# palencia es
# hobart au
# rikitea pf
# khatanga ru
# cape town za
# punta arenas cl
# ushuaia ar
# torbay ca
# chokurdakh ru
# constitucion cl
# atuona pf
# albany au
# cherskiy ru
# saint-philippe re
# ponta do sol cv
# yellowknife ca
# rikitea pf
# nhulunbuy au
# tiznit ma
# vaitupu wf
# georgetown sh
# punta arenas cl
# alofi nu
# punta arenas cl
# abong mbang cm
# busselton au
# rikitea pf
# bluff nz
# rikitea pf
# yellowknife ca
# atuona pf
# kodiak us
# albany au
# victoria sc
# hithadhoo mv
# qaanaaq gl
# tura ru
# port hedland au
# belushya guba ru
# east london za
# tuatapere nz
# hovd mn
# valparaiso cl
# punta arenas cl
# zhangjiakou cn
# bredasdorp za
# karaul ru
# morondava mg
# rikitea pf
# blagodarnyy ru
# qaanaaq gl
# saint-philippe re
# qaanaaq gl
# puerto ayora ec
# yellowknife ca
# punta arenas cl
# gull lake ca
# umm lajj sa
# konza ke
# atuona pf
# jamestown sh
# port hedland au
# iquitos pe
# kapaa us
# new norfolk au
# punta arenas cl
# udachnyy ru
# mahebourg mu
# rikitea pf
# dikson ru
# gravdal no
# chichli in
# wawa ca
# concepcion del oro mx
# ushuaia ar
# kyra ru
# jamestown sh
# puerto ayora ec
# cape town za
# new norfolk au
# hithadhoo mv
# taolanaro mg
# barrow us
# alofi nu
# cape town za
# kahului us
# carnarvon au
# hambantota lk
# georgetown sh
# hilo us
# tiksi ru
# manokwari id
# hithadhoo mv
# leningradskiy ru
# itoman jp
# kondopoga ru
# nemuro jp
# coracora pe
# samarai pg
# nouadhibou mr
# waitati nz
# praia cv
# butaritari ki
# bocas del toro pa
# upernavik gl
# busselton au
# port alfred za
# roebourne au
# hithadhoo mv
# bethel us
# jamestown sh
# jamestown sh
# kungurtug ru
# hamilton bm
# rikitea pf
# bubaque gw
# abonnema ng
# chalons-en-champagne fr
# kualakapuas id
# punta arenas cl
# rikitea pf
# cidreira br
# gwadar pk
# punta arenas cl
# la ronge ca
# guarapuava br
# provideniya ru
# albany au
# busselton au
# nanortalik gl
# severo-kurilsk ru
# luganville vu
# saskylakh ru
# kapaa us
# clyde river ca
# longyearbyen sj
# albany au
# hadrut az
# tambovka ru
# saint anthony ca
# gonaives ht
# kapaa us
# bundaberg au
# tasiilaq gl
# albany au
# yellowknife ca
# butaritari ki
# avarua ck
# starobachaty ru
# taolanaro mg
# solenzo bf
# makaleng bw
# cape town za
# rikitea pf
# nikolskoye ru
# hofn is
# sao geraldo do araguaia br
# tumannyy ru
# hermanus za
# santa rosalia mx
# carballo es
# kapaa us
# nikolskoye ru
# punta arenas cl
# marcona pe
# palmer us
# hermanus za
# sentyabrskiy ru
# grand gaube mu
# gazojak tm
# kavieng pg
# saskylakh ru
# cherskiy ru
# opelousas us
# berlevag no
# ushuaia ar
# mataura pf
# mataura pf
# ladario br
# severo-kurilsk ru
# mount isa au
# bethel us
# yellowknife ca
# rikitea pf
# east london za
# joshimath in
# lata sb
# rikitea pf
# khatanga ru
# yar-sale ru
# barentsburg sj
# vaini to
# thompson ca
# cravo norte co
# porto novo cv
# praia da vitoria pt
# san patricio mx
# vestmannaeyjar is
# vila velha br
# port elizabeth za
# ushuaia ar
# ketchikan us
# vardo no
# busselton au
# rikitea pf
# butaritari ki
# hilo us
# nishihara jp
# sayhat sa
# palu id
# atuona pf
# tyubuk ru
# hervey bay au
# bireun id
# albany au
# ayacucho pe
# orange walk bz
# saint-leu re
# kapaa us
# vardo no
# port elizabeth za
# simao cn
# wazzan ma
# lanxi cn
# aklavik ca
# taolanaro mg
# punta arenas cl
# luderitz na
# lodwar ke
# huilong cn
# rikitea pf
# vostok ru
# albany au
# bredasdorp za
# tsihombe mg
# avera pf
# attawapiskat ca
# tomari ru
# temaraia ki
# londoko ru
# ilulissat gl
# cochrane ca
# galveston us
# east london za
# port hedland au
# kaitangata nz
# burnie au
# cape elizabeth us
# chany ru
# cherskiy ru
# hermanus za
# tual id
# vicksburg us
# taolanaro mg
# lebu cl
# castro cl
# norman wells ca
# cape town za
# taolanaro mg
# teseney er
# toledo es
# jamestown sh
# marawi sd
# zenzeli ru
# hobart au
# rikitea pf
# port elizabeth za
# belushya guba ru
# thompson ca
# busselton au
# vaitupu wf
# burgos ph
# barrow us
# bredasdorp za
# bud no
# tasiilaq gl
# jati id
# ponta do sol cv
# georgetown sh
# cape town za
# biu ng
# san policarpo ph
# college us
# montevideo uy
# bluff nz
# faya td
# necochea ar
# bluff nz
# bredasdorp za
# sangod in
# kommunisticheskiy ru
# provideniya ru
# salamanca cl
# mataura pf
# avarua ck
# dingle ie
# saint george bm
# taolanaro mg
# jamestown sh
# ushuaia ar
# ushuaia ar
# rorvik no
# kelvington ca
# cape town za
# kerman ir
# ushuaia ar
# vestmannaeyjar is
# shingu jp
# hobart au
# gornyy ru
# severnyy ru
# barentsburg sj
# tasiilaq gl
# shetpe kz
# bukama cd
# henties bay na
# avarua ck
# vilhena br
# bluff nz
# bacuit ph
# port alfred za
# khani ru
# hermanus za
# turinsk ru
# hithadhoo mv
# benguela ao
# teeli ru
# cape town za
# vaini to
# georgetown sh
# bokspits bw
# zima ru
# ponta do sol cv
# illoqqortoormiut gl
# galesong id
# hihifo to
# cockburn harbour tc
# illoqqortoormiut gl
# oktyabrskoye ru
# wanaka nz
# chegdomyn ru
# beloha mg
# chagda ru
# yellowknife ca
# souillac mu
# milazzo it
# jamestown sh
# taltal cl
# ahualulco mx
# castro cl
# beringovskiy ru
# kapaa us
# new norfolk au
# ushuaia ar
# rikitea pf
# new norfolk au
# busselton au
# georgetown sh
# kathmandu np
# ilulissat gl
# sakakah sa
# pensacola us
# mawlaik mm
# jamestown sh
# hermanus za
# cape town za
# hervey bay au
# barrow us
# deori khas in
# barrow us
# nizhneyansk ru
# busselton au
# wanning cn
# bluff nz
# yar-sale ru
# fort nelson ca
# cefalu it
# hermanus za
# bitkine td
# albany au
# illoqqortoormiut gl
# willowmore za
# utrecht za
# castro cl
# sao filipe cv
# atuona pf
# ushuaia ar
# oulainen fi
# busselton au
# chuy uy
# hithadhoo mv
# mount isa au
# ahipara nz
# katsuura jp
# kapandrition gr
# airai pw
# la rioja ar
# taolanaro mg
# tessalit ml
# brufut gm
# luan cn
# tasiilaq gl
# katsuura jp
# cape town za
# bluff nz
# verkhoyansk ru
# saskylakh ru
# castro cl
# bredasdorp za
# illoqqortoormiut gl
# avarua ck
# torbay ca
# kaitangata nz
# belushya guba ru
# alyangula au
# qingan cn
# talaya ru
# port alfred za
# castro cl
# rikitea pf
# ushuaia ar
# cape town za
# severo-kurilsk ru
# fairbanks us
# rikitea pf
# bonavista ca
# sembe cg
# pevek ru
# lodwar ke
# seoul kr
# kodiak us
# port lincoln au
# palabuhanratu id
# albany au
# vaitupu wf
# jalu ly
# meulaboh id
# ushuaia ar
# albany au
# pergamino ar
# hermanus za
# atuona pf
# butaritari ki
# cape town za
# iralaya hn
# puerto baquerizo moreno ec
# lagoa pt
# port elizabeth za
# esperance au
# mys shmidta ru
# chokurdakh ru
# havre us
# bredasdorp za
# springbok za
# huarmey pe
# hamilton bm
# suba ph
# unity ca
# davila ph
# yar-sale ru
# atamanovka ru
# pacifica us
# busselton au
# illoqqortoormiut gl
# longyearbyen sj
# east london za
# puerto ayora ec
# hagerstown us
# jamestown sh
# albany au
# ushuaia ar
# louisbourg ca
# jaru br
# trairi br
# taolanaro mg
# brae gb
# jamestown sh
# mys shmidta ru
# qaqortoq gl
# cabo san lucas mx
# hambantota lk
# vaini to
# zaozerne ua
# bonavista ca
# chapais ca
# geraldton au
# ushuaia ar
# arawa pg
# salmon creek us
# kailua us
# pevek ru
# rikitea pf
# jujuy ar
# paamiut gl
# punta arenas cl
# afmadu so
# rikitea pf
# hermanus za
# rikitea pf
# yellowknife ca
# tuatapere nz
# saskylakh ru
# rikitea pf
# hermanus za
# puerto ayora ec
# hermanus za
# kapaa us
# ushuaia ar
# cape town za
# san patricio mx
# saint-philippe re
# havelock us
# belushya guba ru
# caravelas br
# illoqqortoormiut gl
# nanortalik gl
# rikitea pf
# lewistown us
# bluff nz
# bluff nz
# norman wells ca
# barrow us
# diapaga bf
# hermanus za
# buala sb
# olafsvik is
# cabo san lucas mx
# clyde river ca
# albany au
# punta arenas cl
# bluff nz
# anadyr ru
# thompson ca
# hermanus za
# attawapiskat ca
# albany au
# eureka us
# husavik is
# souillac mu
# aksarka ru
# atuona pf
# norman wells ca
# vaini to
# bluff nz
# new norfolk au
# barentsburg sj
# porto velho br
# cayenne gf
# bayir jo
# dingle ie
# dhandhuka in
# ponta do sol cv
# geraldton au
# barrow us
# leshukonskoye ru
# taolanaro mg
# labuan my
# khatanga ru
# college us
# severo-kurilsk ru
# butaritari ki
# huangpi cn
# bluff nz
# luderitz na
# samusu ws
# bredasdorp za
# torbay ca
# arica cl
# gashua ng
# bluff nz
# bluff nz
# ushuaia ar
# port hedland au
# taolanaro mg
# lebu cl
# ushuaia ar
# port-cartier ca
# vostok ru
# ushuaia ar
# georgetown sh
# cidreira br
# axim gh
# lagoa pt
# rikitea pf
# buraydah sa
# severo-kurilsk ru
# auki sb
# ribeira grande pt
# rikitea pf
# nanortalik gl
# eureka us
# nizhneyansk ru
# mataura pf
# vaini to
# carnarvon au
# rupert us
# christchurch nz
# nikolskoye ru
# saint george bm
# vaini to
# tasiilaq gl
# rikitea pf
# saskylakh ru
# mataura pf
# mahebourg mu
# makinsk kz
# maarianhamina fi
# honiara sb
# nizhneyansk ru
# constitucion mx
# srandakan id
# hithadhoo mv
# meyungs pw
# doha kw
# pinotepa nacional mx
# anjar in
# butaritari ki
# illoqqortoormiut gl
# port hardy ca
# bowen au
# ushuaia ar
# rapid city us
# carnarvon au
# tasiilaq gl
# kapaa us
# kapaa us
# oktyabrskiy ru
# taolanaro mg
# kruisfontein za
# kutum sd
# rikitea pf
# atuona pf
# mayumba ga
# tuktoyaktuk ca
# krasnoselkup ru
# san cristobal ec
# saint-philippe re
# hermanus za
# tuktoyaktuk ca
# punta arenas cl
# souillac mu
# kaitangata nz
# avarua ck
# winnemucca us
# kavaratti in
# mar del plata ar
# aklavik ca
# ryotsu jp
# atuona pf
# hermanus za
# svetlyy ru
# rikitea pf
# marawi sd
# willmar us
# saint-augustin ca
# yellowknife ca
# butaritari ki
# price ca
# sao filipe cv
# dingle ie
# bridlington gb
# provideniya ru
# pingliang cn
# avarua ck
# batagay-alyta ru
# jamestown sh
# iqaluit ca
# ushuaia ar
# haines junction ca
# inta ru
# litovko ru
# punta arenas cl
# atuona pf
# port alfred za
# ushuaia ar
# laguna br
# albany au
# vila franca do campo pt
# bambous virieux mu
# rikitea pf
# saint-philippe re
# arraial do cabo br
# rikitea pf
# praxedis guerrero mx
# mataura pf
# ayaviri pe
# torbay ca
# bambous virieux mu
# cidreira br
# nijar es
# mataura pf
# ushuaia ar
# soyo ao
# kapaa us
# bandarbeyla so
# noumea nc
# terney ru
# torbay ca
# salalah om
# lompoc us
# butaritari ki
# victoria sc
# tessalit ml
# amderma ru
# chirongui yt
# punta arenas cl
# lolua tv
# narsaq gl
# georgetown sh
# belushya guba ru
# hamilton bm
# barrow us
# qaanaaq gl
# kavieng pg
# alyangula au
# barra do bugres br
# petukhovo ru
# hobart au
# mataura pf
# okhotsk ru
# pisco pe
# provideniya ru
# laukaa fi
# busselton au
# ushuaia ar
# visnes no
# punta arenas cl
# port alfred za
# murgab tm
# mahebourg mu
# talnakh ru
# chapais ca
# hobart au
# isangel vu
# mataura pf
# illoqqortoormiut gl
# mar del plata ar
# chacabuco ar
# ushuaia ar
# port alfred za
# cape town za
# punta arenas cl
# seara br
# normandin ca
# pizarro co
# qaanaaq gl
# chokurdakh ru
# chokurdakh ru
# kuche cn
# vila franca do campo pt
# albany au
# royan fr
# norman wells ca
# rikitea pf
# sorong id
# ancud cl
# kapaa us
# jumla np
# georgetown sh
# belmonte br
# saint-philippe re
# alwar in
# babstovo ru
# georgetown sh
# bredasdorp za
# cabra ph
# samusu ws
# codrington ag
# gambela et
# nikolskoye ru
# albany au
# vaitupu wf
# vaini to
# busselton au
# attawapiskat ca
# iqaluit ca
# cabo san lucas mx
# yellowknife ca
# iqaluit ca
# hamilton bm
# la rioja ar
# saint-philippe re
# beyneu kz
# naze jp
# barrow us
# yellowknife ca
# sao filipe cv
# arraial do cabo br
# lebu cl
# bethel us
# lensk ru
# clyde river ca
# dzilam gonzalez mx
# morros br
# new norfolk au
# san quintin mx
# morant bay jm
# busselton au
# tiksi ru
# rikitea pf
# kuche cn
# hobart au
# pisco pe
# andenes no
# punta arenas cl
# palu id
# ushuaia ar
# lenger kz
# bredasdorp za
# burica pa
# castro cl
# tupik ru
# smithers ca
# srednekolymsk ru
# punta arenas cl
# pevek ru
# sri aman my
# puerto ayora ec
# albany au
# mizan teferi et
# cayenne gf
# rocha uy
# geraldton ca
# hobart au
# belushya guba ru
# bireun id
# linares cl
# marystown ca
# santarem br
# ushuaia ar
# puerto ayora ec
# georgetown sh
# chapais ca
# ponta do sol cv
# sentyabrskiy ru
# upernavik gl
# thompson ca
# rabo de peixe pt
# hermanus za
# dikson ru
# barbar sd
# saldanha za
# nishihara jp
# clyde river ca
# rikitea pf
# kupang id
# tiksi ru
# yellowknife ca
# hobart au
# nioro sn
# port elizabeth vc
# thompson ca
# carnarvon au
# forestville ca
# port alfred za
# santo antonio do sudoeste br
# olinda br
# airai pw
# rikitea pf
# wattegama lk
# saint-philippe re
# thompson ca
# vaini to
# kholm af
# ampanihy mg
# pisco pe
# cape town za
# college us
# rikitea pf
# port alfred za
# qaanaaq gl
# jojoima sl
# clyde river ca
# kruisfontein za
# verkhnyaya khava ru
# vanimo pg
# bluff nz
# ponta do sol cv
# east london za
# rikitea pf
# albany au
# amderma ru
# sitka us
# punta arenas cl
# morehead pg
# ulmu ro
# georgetown sh
# olga ru
# tosya tr
# saskylakh ru
# sakakah sa
# saskylakh ru
# joshimath in
# longyearbyen sj
# khandyga ru
# punta arenas cl
# tiksi ru
# kodiak us
# pisco pe
# khatanga ru
# puerto ayora ec
# asau tv
# bengkulu id
# achisay kz
# busselton au
# taolanaro mg
# mataura pf
# georgetown sh
# cape town za
# kaeo nz
# vaini to
# barrow us
# hermanus za
# castro cl
# jamestown sh
# mataura pf
# lagoa pt
# tongliao cn
# iqaluit ca
# busselton au
# belousovka kz
# taolanaro mg
# saint george bm
# almenara br
# rikitea pf
# mareeba au
# rio gallegos ar
# mar del plata ar
# rikitea pf
# kartuzy pl
# belyy yar ru
# bluff nz
# nikolskoye ru
# mataura pf
# carolina br
# qaanaaq gl
# san vicente cl
# broken hill au
# nikolskoye ru
# vaini to
# xuddur so
# bethel us
# avarua ck
# port alfred za
# thompson ca
# tiksi ru
# saskylakh ru
# eregli tr
# valparaiso cl
# busselton au
# hobyo so
# maturin ve
# longyearbyen sj
# illoqqortoormiut gl
# marsh harbour bs
# punta arenas cl
# vaini to
# camopi gf
# niquero cu
# krasnoselkup ru
# portland au
# ponta do sol cv
# mongo td
# iaciara br
# rikitea pf
# tiksi ru
# ilulissat gl
# vaini to
# mesa us
# tuatapere nz
# mataura pf
# hilo us
# shizunai jp
# mataura pf
# yarmouth ca
# hermanus za
# rikitea pf
# cape town za
# belushya guba ru
# karratha au
# black river jm
# ranong th
# tessalit ml
# ferrandina it
# aleksandrov gay ru
# saleaula ws
# jamestown sh
# isangel vu
# luderitz na
# rikitea pf
# manzhouli cn
# suining cn
# san cristobal ec
# esperance au
# pemba mz
# darhan mn
# mataura pf
# barrow us
# tasiilaq gl
# albany au
# dali cn
# albany au
# alofi nu
# taolanaro mg
# georgetown sh
# puerto ayora ec
# albany au
# turayf sa
# skelleftea se
# georgetown sh
# mataura pf
# mehamn no
# lubao cd
# talnakh ru
# saint-philippe re
# albany au
# ushuaia ar
# moron mn
# jamestown sh
# upernavik gl
# kapaa us
# hilo us
# fairbanks us
# baranain es
# butaritari ki
# fortuna us
# butaritari ki
# yar-sale ru
# illoqqortoormiut gl
# pokhara np
# jamestown sh
# samusu ws
# kiunga pg
# bredasdorp za
# denpasar id
# saskylakh ru
# chapais ca
# illoqqortoormiut gl
# hermanus za
# bemidji us
# kapaa us
# necaxa mx
# ushuaia ar
# lompoc us
# taolanaro mg
# hermanus za
# iranshahr ir
# buluang ph
# puerto quijarro bo
# busselton au
# lazo ru
# esperance au
# bairnsdale au
# busselton au
# coihaique cl
# grindavik is
# itaituba br
# port alfred za
# foca ba
# kodiak us
# carnarvon au
# fereydun kenar ir
# verkhnevilyuysk ru
# karratha au
# jinxiang cn
# louisbourg ca
# parabel ru
# ribeira grande pt
# punta arenas cl
# sheridan us
# mataura pf
# tiksi ru
# nikolskoye ru
# east london za
# mataura pf
# trinidad uy
# chapais ca
# samusu ws
# puerto ayora ec
# mataura pf
# sao joao batista br
# rocha uy
# new norfolk au
# airai pw
# ribeira grande pt
# half moon bay us
# ushuaia ar
# saint-philippe re
# airai pw
# puerto ayora ec
# albany au
# amderma ru
# carlos antonio lopez py
# ribeira grande pt
# bolkhov ru
# hobart au
# waycross us
# barrow us
# fortuna us
# haines junction ca
# bluff nz
# adrar dz
# kudahuvadhoo mv
# klaksvik fo
# puerto escondido mx
# mys shmidta ru
# busselton au
# kasongo cd
# bandar-e lengeh ir
# santa fe us
# skaudvile lt
# nampula mz
# vaini to
# itarema br
# lompoc us
# butaritari ki
# kapaa us
# rikitea pf
# provideniya ru
# jamestown sh
# longyearbyen sj
# fortuna us
# talnakh ru
# tiksi ru
# makakilo city us
# hobart au
# rio grande br
# cabo san lucas mx
# hasaki jp
# noumea nc
# illoqqortoormiut gl
# jamestown sh
# bredasdorp za
# inhambane mz
# ushuaia ar
# busselton au
# illoqqortoormiut gl
# ostrovnoy ru
# port elizabeth za
# olavarria ar
# rikitea pf
# karaul ru
# camacha pt
# rikitea pf
# sinkat sd
# nanortalik gl
# hithadhoo mv
# fortuna us
# vila velha br
# batticaloa lk
# yangjiang cn
# avarua ck
# kapaa us
# bambous virieux mu
# bonavista ca
# new norfolk au
# vila velha br
# edd er
# busselton au
# mar del plata ar
# busselton au
# hansot in
# busselton au
# oksfjord no
# jamestown sh
# hobyo so
# castro cl
# yumen cn
# marcona pe
# mar del plata ar
# proletarskiy ru
# nikolskoye ru
# amahai id
# black river jm
# itarema br
# thompson ca
# sharqpur pk
# tuktoyaktuk ca
# villarrica co
# geraldton au
# torbay ca
# pacific grove us
# praia da vitoria pt
# yerbogachen ru
# geraldton au
# chuy uy
# punta arenas cl
# rikitea pf
# nikolskoye ru
# norman wells ca
# new norfolk au
# otane nz
# presidencia roque saenz pena ar
# yingshang cn
# turukhansk ru
# hilo us
# puerto ayora ec
# albany au
# punta arenas cl
# warsaw us
# buala sb
# bolsheustikinskoye ru
# qaanaaq gl
# hithadhoo mv
# okahandja na
# ushuaia ar
# barentsburg sj
# hobart au
# sitka us
# fort nelson ca
# saint-francois gp
# la ronge ca
# shirokiy ru
# hobart au
# young au
# alekseyevsk ru
# yellowknife ca
# utiroa ki
# grand river south east mu
# boa vista br
# rikitea pf
# daru pg
# bosaso so
# bay roberts ca
# hermanus za
# rafaela ar
# kupang id
# kodiak us
# marawi sd
# punta arenas cl
# haimen cn
# verkhnevilyuysk ru
# taolanaro mg
# sola vu
# lompoc us
# hobart au
# puerto ayora ec
# djibo bf
# dunedin nz
# longyearbyen sj
# port alfred za
# punta arenas cl
# el mante mx
# atuona pf
# albany au
# taolanaro mg
# springville us
# dubbo au
# verdun fr
# riyadh sa
# mount gambier au
# yellowknife ca
# kavieng pg
# albany au
# caala ao
# bathsheba bb
# vaitupu wf
# lamar us
# kapaa us
# hilo us
# amderma ru
# chuy uy
# ures mx
# yerbogachen ru
# torbay ca
# carnarvon au
# grand river south east mu
# la ronge ca
# upernavik gl
# natal br
# kruisfontein za
# nizhneyansk ru
# barrow us
# pahrump us
# busselton au
# mastung pk
# kodiak us
# gisborne nz
# vao nc
# ushuaia ar
# nemuro jp
# marzuq ly
# puerto ayora ec
# dingle ie
# ushuaia ar
# taolanaro mg
# barrow us
# rikitea pf
# tuktoyaktuk ca
# mount gambier au
# fez ma
# athabasca ca
# illoqqortoormiut gl
# tura ru
# puerto ayora ec
# kapaa us
# karkaralinsk kz
# castro cl
# samusu ws
# khatanga ru
# yhu py
# ribeira grande pt
# victor harbor au
# punta arenas cl
# mys shmidta ru
# butaritari ki
# busselton au
# pisco pe
# sulphur springs us
# albany au
# barrow us
# atuona pf
# rikitea pf
# yar-sale ru
# grindavik is
# rawson ar
# tasiilaq gl
# puerto de la cruz es

# %%
# Create a list for holding the cities

cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the list of cities list
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficinet count

len(cities)
# Out:
# 629

# %%
# Import the requests library

import requests

# Import the API key

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=48736fafa44bf7319fdea9b3b0e4a6be&q=Boston

# %%
# Make a 'Get' request for the city weather

city_weather = requests.get(city_url)

city_weather.status_code
# Out:
# 200

# %%
# Get the text of the 'Get' request

city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}],"base":"stations","main":{"temp":33.89,"feels_like":21.97,"temp_min":31.66,"temp_max":35.98,"pressure":1016,"humidity":60},"visibility":10000,"wind":{"speed":21.85,"deg":310,"gust":28.77},"clouds":{"all":20},"dt":1671054022,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1671019549,"sunset":1671052331},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON tet of the 'Get' request

city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 33.89,
#   'feels_like': 21.97,
#   'temp_min': 31.66,
#   'temp_max': 35.98,
#   'pressure': 1016,
#   'humidity': 60},
#  'visibility': 10000,
#  'wind': {'speed': 21.85, 'deg': 310, 'gust': 28.77},
#  'clouds': {'all': 20},
#  'dt': 1671054022,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1671019549,
#   'sunset': 1671052331},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city

city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City Weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city

city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 33.89,
#   'feels_like': 21.97,
#   'temp_min': 31.66,
#   'temp_max': 35.98,
#   'pressure': 1016,
#   'humidity': 60},
#  'visibility': 10000,
#  'wind': {'speed': 21.85, 'deg': 310, 'gust': 28.77},
#  'clouds': {'all': 20},
#  'dt': 1671054022,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1671019549,
#   'sunset': 1671052331},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# get the JSON data

boston_data = city_weather.json()
boston_data["sys"]['country']
# Out:
# 'US'

# %%
boston_data["dt"]
# Out:
# 1671054022

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 35.98 60 20 21.85

# %%
# Import the datetime module from the datetime library

from datetime import datetime

# Get the date from the JSON file

date = boston_data["dt"]

# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds

datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 12, 14, 21, 40, 22)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-12-14 21:40:22'

# %%
# Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data retrieval      ")
print("------------------------------")

# Create counter.

record_count = 1

set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
    # Add 1 to the record count
    
    record_count +=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data retrieval
# ------------------------------
# Processing Record 1 of Set 1 | flinders
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | maumere
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | rawah
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | karratha
# Processing Record 10 of Set 1 | halifax
# Processing Record 11 of Set 1 | khandyga
# Processing Record 12 of Set 1 | punto fijo
# Processing Record 13 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | meulaboh
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 1 | morehead
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | balkhash
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | souris
# Processing Record 30 of Set 1 | waipawa
# Processing Record 31 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 37 of Set 1 | grimshaw
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | praia da vitoria
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | lai
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | weligama
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | luangwa
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | luganville
# Processing Record 4 of Set 2 | isangel
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | sisimiut
# Processing Record 7 of Set 2 | teahupoo
# Processing Record 8 of Set 2 | balozi
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | san patricio
# Processing Record 13 of Set 2 | san quintin
# Processing Record 14 of Set 2 | killybegs
# Processing Record 15 of Set 2 | tautira
# Processing Record 16 of Set 2 | igarapava
# Processing Record 17 of Set 2 | turukhansk
# Processing Record 18 of Set 2 | vao
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | henties bay
# Processing Record 21 of Set 2 | banff
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | peleduy
# Processing Record 29 of Set 2 | sale
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | kaohsiung
# Processing Record 32 of Set 2 | mar del plata
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | wad madani
# Processing Record 35 of Set 2 | mount isa
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | southbridge
# Processing Record 38 of Set 2 | vangaindrano
# Processing Record 39 of Set 2 | komsomolskiy
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | raudeberg
# Processing Record 44 of Set 2 | alta floresta
# Processing Record 45 of Set 2 | bath
# Processing Record 46 of Set 2 | atar
# Processing Record 47 of Set 2 | esso
# Processing Record 48 of Set 2 | toropets
# Processing Record 49 of Set 2 | grass valley
# Processing Record 50 of Set 2 | ayan
# Processing Record 1 of Set 3 | kiunga
# Processing Record 2 of Set 3 | nuuk
# Processing Record 3 of Set 3 | ewo
# Processing Record 4 of Set 3 | gayny
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | san vicente
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | kargasok
# Processing Record 11 of Set 3 | axim
# Processing Record 12 of Set 3 | yerbogachen
# Processing Record 13 of Set 3 | las choapas
# Processing Record 14 of Set 3 | homer
# Processing Record 15 of Set 3 | veraval
# Processing Record 16 of Set 3 | faya
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | coahuayana
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | tuy hoa
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | umba
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | blatnica
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | fortuna
# Processing Record 29 of Set 3 | marathon
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | igarka
# Processing Record 32 of Set 3 | palencia
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | nhulunbuy
# Processing Record 39 of Set 3 | tiznit
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | abong mbang
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | tura
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | hovd
# Processing Record 49 of Set 3 | valparaiso
# Processing Record 50 of Set 3 | zhangjiakou
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | morondava
# Processing Record 3 of Set 4 | blagodarnyy
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | gull lake
# Processing Record 6 of Set 4 | umm lajj
# Processing Record 7 of Set 4 | konza
# Processing Record 8 of Set 4 | jamestown
# Processing Record 9 of Set 4 | iquitos
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | udachnyy
# Processing Record 12 of Set 4 | gravdal
# Processing Record 13 of Set 4 | chichli
# Processing Record 14 of Set 4 | wawa
# Processing Record 15 of Set 4 | concepcion del oro
# Processing Record 16 of Set 4 | kyra
# Processing Record 17 of Set 4 | kahului
# Processing Record 18 of Set 4 | hambantota
# Processing Record 19 of Set 4 | manokwari
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | itoman
# Processing Record 22 of Set 4 | kondopoga
# Processing Record 23 of Set 4 | nemuro
# Processing Record 24 of Set 4 | coracora
# Processing Record 25 of Set 4 | samarai
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | waitati
# Processing Record 28 of Set 4 | praia
# Processing Record 29 of Set 4 | bocas del toro
# Processing Record 30 of Set 4 | roebourne
# Processing Record 31 of Set 4 | kungurtug
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | abonnema
# Processing Record 35 of Set 4 | chalons-en-champagne
# Processing Record 36 of Set 4 | kualakapuas
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | gwadar
# Processing Record 39 of Set 4 | guarapuava
# Processing Record 40 of Set 4 | nanortalik
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | saskylakh
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | hadrut
# Processing Record 45 of Set 4 | tambovka
# Processing Record 46 of Set 4 | saint anthony
# Processing Record 47 of Set 4 | gonaives
# Processing Record 48 of Set 4 | bundaberg
# Processing Record 49 of Set 4 | starobachaty
# Processing Record 50 of Set 4 | solenzo
# Processing Record 1 of Set 5 | makaleng
# Processing Record 2 of Set 5 | hofn
# Processing Record 3 of Set 5 | sao geraldo do araguaia
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | santa rosalia
# Processing Record 6 of Set 5 | carballo
# Processing Record 7 of Set 5 | palmer
# Processing Record 8 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | grand gaube
# Processing Record 10 of Set 5 | gazojak
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | opelousas
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | ladario
# Processing Record 15 of Set 5 | joshimath
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | yar-sale
# Processing Record 18 of Set 5 | vaini
# Processing Record 19 of Set 5 | cravo norte
# Processing Record 20 of Set 5 | porto novo
# Processing Record 21 of Set 5 | vestmannaeyjar
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | ketchikan
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | nishihara
# Processing Record 27 of Set 5 | sayhat
# Processing Record 28 of Set 5 | palu
# Processing Record 29 of Set 5 | tyubuk
# Processing Record 30 of Set 5 | hervey bay
# Processing Record 31 of Set 5 | bireun
# Processing Record 32 of Set 5 | ayacucho
# Processing Record 33 of Set 5 | orange walk
# Processing Record 34 of Set 5 | saint-leu
# Processing Record 35 of Set 5 | simao
# Processing Record 36 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 37 of Set 5 | lanxi
# Processing Record 38 of Set 5 | aklavik
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | lodwar
# Processing Record 41 of Set 5 | huilong
# Processing Record 42 of Set 5 | vostok
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | tomari
# Processing Record 47 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 5 | londoko
# Processing Record 49 of Set 5 | ilulissat
# Processing Record 50 of Set 5 | cochrane
# Processing Record 1 of Set 6 | galveston
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | burnie
# Processing Record 4 of Set 6 | cape elizabeth
# City not found. Skipping...
# Processing Record 5 of Set 6 | chany
# Processing Record 6 of Set 6 | tual
# Processing Record 7 of Set 6 | vicksburg
# Processing Record 8 of Set 6 | lebu
# Processing Record 9 of Set 6 | teseney
# Processing Record 10 of Set 6 | toledo
# Processing Record 11 of Set 6 | marawi
# Processing Record 12 of Set 6 | zenzeli
# Processing Record 13 of Set 6 | burgos
# Processing Record 14 of Set 6 | bud
# Processing Record 15 of Set 6 | jati
# Processing Record 16 of Set 6 | biu
# Processing Record 17 of Set 6 | san policarpo
# Processing Record 18 of Set 6 | college
# Processing Record 19 of Set 6 | montevideo
# Processing Record 20 of Set 6 | necochea
# Processing Record 21 of Set 6 | sangod
# Processing Record 22 of Set 6 | kommunisticheskiy
# Processing Record 23 of Set 6 | salamanca
# Processing Record 24 of Set 6 | dingle
# Processing Record 25 of Set 6 | rorvik
# Processing Record 26 of Set 6 | kelvington
# Processing Record 27 of Set 6 | kerman
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | gornyy
# Processing Record 30 of Set 6 | severnyy
# Processing Record 31 of Set 6 | shetpe
# Processing Record 32 of Set 6 | bukama
# Processing Record 33 of Set 6 | vilhena
# Processing Record 34 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 35 of Set 6 | khani
# Processing Record 36 of Set 6 | turinsk
# Processing Record 37 of Set 6 | benguela
# Processing Record 38 of Set 6 | teeli
# Processing Record 39 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 6 | zima
# Processing Record 41 of Set 6 | galesong
# Processing Record 42 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 6 | oktyabrskoye
# Processing Record 45 of Set 6 | wanaka
# Processing Record 46 of Set 6 | chegdomyn
# Processing Record 47 of Set 6 | beloha
# Processing Record 48 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 6 | souillac
# Processing Record 50 of Set 6 | milazzo
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | ahualulco
# Processing Record 3 of Set 7 | beringovskiy
# Processing Record 4 of Set 7 | kathmandu
# Processing Record 5 of Set 7 | sakakah
# Processing Record 6 of Set 7 | pensacola
# Processing Record 7 of Set 7 | mawlaik
# Processing Record 8 of Set 7 | deori khas
# Processing Record 9 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 7 | wanning
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | cefalu
# Processing Record 13 of Set 7 | bitkine
# Processing Record 14 of Set 7 | willowmore
# Processing Record 15 of Set 7 | utrecht
# Processing Record 16 of Set 7 | sao filipe
# Processing Record 17 of Set 7 | oulainen
# Processing Record 18 of Set 7 | ahipara
# Processing Record 19 of Set 7 | katsuura
# Processing Record 20 of Set 7 | kapandrition
# City not found. Skipping...
# Processing Record 21 of Set 7 | la rioja
# Processing Record 22 of Set 7 | tessalit
# Processing Record 23 of Set 7 | brufut
# Processing Record 24 of Set 7 | luan
# Processing Record 25 of Set 7 | verkhoyansk
# Processing Record 26 of Set 7 | alyangula
# Processing Record 27 of Set 7 | qingan
# City not found. Skipping...
# Processing Record 28 of Set 7 | talaya
# Processing Record 29 of Set 7 | bonavista
# Processing Record 30 of Set 7 | sembe
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | seoul
# Processing Record 33 of Set 7 | port lincoln
# Processing Record 34 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 7 | jalu
# Processing Record 36 of Set 7 | pergamino
# Processing Record 37 of Set 7 | iralaya
# Processing Record 38 of Set 7 | puerto baquerizo moreno
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | esperance
# Processing Record 41 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 7 | havre
# Processing Record 43 of Set 7 | springbok
# Processing Record 44 of Set 7 | huarmey
# Processing Record 45 of Set 7 | suba
# Processing Record 46 of Set 7 | unity
# Processing Record 47 of Set 7 | davila
# Processing Record 48 of Set 7 | atamanovka
# Processing Record 49 of Set 7 | pacifica
# Processing Record 50 of Set 7 | hagerstown
# Processing Record 1 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 8 | jaru
# Processing Record 3 of Set 8 | trairi
# Processing Record 4 of Set 8 | brae
# Processing Record 5 of Set 8 | qaqortoq
# Processing Record 6 of Set 8 | cabo san lucas
# Processing Record 7 of Set 8 | zaozerne
# Processing Record 8 of Set 8 | chapais
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | arawa
# Processing Record 11 of Set 8 | salmon creek
# Processing Record 12 of Set 8 | kailua
# Processing Record 13 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 14 of Set 8 | paamiut
# Processing Record 15 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | caravelas
# Processing Record 18 of Set 8 | lewistown
# Processing Record 19 of Set 8 | diapaga
# Processing Record 20 of Set 8 | buala
# Processing Record 21 of Set 8 | olafsvik
# Processing Record 22 of Set 8 | anadyr
# Processing Record 23 of Set 8 | eureka
# Processing Record 24 of Set 8 | aksarka
# Processing Record 25 of Set 8 | porto velho
# Processing Record 26 of Set 8 | cayenne
# Processing Record 27 of Set 8 | bayir
# Processing Record 28 of Set 8 | dhandhuka
# Processing Record 29 of Set 8 | leshukonskoye
# Processing Record 30 of Set 8 | labuan
# Processing Record 31 of Set 8 | huangpi
# Processing Record 32 of Set 8 | arica
# Processing Record 33 of Set 8 | gashua
# Processing Record 34 of Set 8 | port-cartier
# Processing Record 35 of Set 8 | buraydah
# Processing Record 36 of Set 8 | auki
# Processing Record 37 of Set 8 | ribeira grande
# Processing Record 38 of Set 8 | rupert
# Processing Record 39 of Set 8 | christchurch
# Processing Record 40 of Set 8 | makinsk
# Processing Record 41 of Set 8 | maarianhamina
# Processing Record 42 of Set 8 | honiara
# Processing Record 43 of Set 8 | srandakan
# Processing Record 44 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 8 | doha
# Processing Record 46 of Set 8 | pinotepa nacional
# Processing Record 47 of Set 8 | anjar
# Processing Record 48 of Set 8 | port hardy
# Processing Record 49 of Set 8 | bowen
# Processing Record 50 of Set 8 | rapid city
# Processing Record 1 of Set 9 | oktyabrskiy
# Processing Record 2 of Set 9 | kruisfontein
# Processing Record 3 of Set 9 | kutum
# Processing Record 4 of Set 9 | mayumba
# Processing Record 5 of Set 9 | krasnoselkup
# Processing Record 6 of Set 9 | san cristobal
# Processing Record 7 of Set 9 | winnemucca
# Processing Record 8 of Set 9 | kavaratti
# Processing Record 9 of Set 9 | ryotsu
# Processing Record 10 of Set 9 | svetlyy
# Processing Record 11 of Set 9 | willmar
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | price
# Processing Record 14 of Set 9 | bridlington
# Processing Record 15 of Set 9 | pingliang
# Processing Record 16 of Set 9 | batagay-alyta
# Processing Record 17 of Set 9 | haines junction
# Processing Record 18 of Set 9 | inta
# Processing Record 19 of Set 9 | litovko
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | bambous virieux
# Processing Record 23 of Set 9 | praxedis guerrero
# Processing Record 24 of Set 9 | ayaviri
# Processing Record 25 of Set 9 | nijar
# Processing Record 26 of Set 9 | soyo
# Processing Record 27 of Set 9 | bandarbeyla
# Processing Record 28 of Set 9 | noumea
# Processing Record 29 of Set 9 | terney
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 9 | chirongui
# Processing Record 33 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 9 | narsaq
# Processing Record 35 of Set 9 | barra do bugres
# Processing Record 36 of Set 9 | petukhovo
# Processing Record 37 of Set 9 | okhotsk
# Processing Record 38 of Set 9 | pisco
# Processing Record 39 of Set 9 | laukaa
# Processing Record 40 of Set 9 | visnes
# Processing Record 41 of Set 9 | murgab
# Processing Record 42 of Set 9 | talnakh
# Processing Record 43 of Set 9 | chacabuco
# Processing Record 44 of Set 9 | seara
# Processing Record 45 of Set 9 | normandin
# Processing Record 46 of Set 9 | pizarro
# Processing Record 47 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 9 | royan
# Processing Record 49 of Set 9 | sorong
# Processing Record 50 of Set 9 | ancud
# Processing Record 1 of Set 10 | jumla
# Processing Record 2 of Set 10 | belmonte
# Processing Record 3 of Set 10 | alwar
# Processing Record 4 of Set 10 | babstovo
# Processing Record 5 of Set 10 | cabra
# Processing Record 6 of Set 10 | codrington
# Processing Record 7 of Set 10 | gambela
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | naze
# Processing Record 10 of Set 10 | lensk
# Processing Record 11 of Set 10 | dzilam gonzalez
# Processing Record 12 of Set 10 | morros
# Processing Record 13 of Set 10 | morant bay
# Processing Record 14 of Set 10 | andenes
# Processing Record 15 of Set 10 | lenger
# Processing Record 16 of Set 10 | burica
# City not found. Skipping...
# Processing Record 17 of Set 10 | tupik
# Processing Record 18 of Set 10 | smithers
# Processing Record 19 of Set 10 | srednekolymsk
# Processing Record 20 of Set 10 | sri aman
# Processing Record 21 of Set 10 | mizan teferi
# Processing Record 22 of Set 10 | rocha
# Processing Record 23 of Set 10 | linares
# Processing Record 24 of Set 10 | marystown
# Processing Record 25 of Set 10 | santarem
# Processing Record 26 of Set 10 | rabo de peixe
# Processing Record 27 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 10 | saldanha
# Processing Record 29 of Set 10 | kupang
# Processing Record 30 of Set 10 | nioro
# Processing Record 31 of Set 10 | forestville
# Processing Record 32 of Set 10 | santo antonio do sudoeste
# Processing Record 33 of Set 10 | olinda
# Processing Record 34 of Set 10 | wattegama
# Processing Record 35 of Set 10 | kholm
# Processing Record 36 of Set 10 | ampanihy
# Processing Record 37 of Set 10 | jojoima
# Processing Record 38 of Set 10 | verkhnyaya khava
# Processing Record 39 of Set 10 | vanimo
# Processing Record 40 of Set 10 | sitka
# Processing Record 41 of Set 10 | ulmu
# Processing Record 42 of Set 10 | olga
# Processing Record 43 of Set 10 | tosya
# Processing Record 44 of Set 10 | asau
# Processing Record 45 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 46 of Set 10 | kaeo
# Processing Record 47 of Set 10 | tongliao
# Processing Record 48 of Set 10 | belousovka
# Processing Record 49 of Set 10 | almenara
# Processing Record 50 of Set 10 | mareeba
# Processing Record 1 of Set 11 | rio gallegos
# Processing Record 2 of Set 11 | kartuzy
# Processing Record 3 of Set 11 | belyy yar
# Processing Record 4 of Set 11 | carolina
# Processing Record 5 of Set 11 | broken hill
# Processing Record 6 of Set 11 | xuddur
# Processing Record 7 of Set 11 | eregli
# Processing Record 8 of Set 11 | hobyo
# Processing Record 9 of Set 11 | maturin
# Processing Record 10 of Set 11 | marsh harbour
# Processing Record 11 of Set 11 | camopi
# Processing Record 12 of Set 11 | niquero
# Processing Record 13 of Set 11 | portland
# Processing Record 14 of Set 11 | mongo
# Processing Record 15 of Set 11 | iaciara
# Processing Record 16 of Set 11 | mesa
# Processing Record 17 of Set 11 | shizunai
# Processing Record 18 of Set 11 | yarmouth
# Processing Record 19 of Set 11 | black river
# Processing Record 20 of Set 11 | ranong
# Processing Record 21 of Set 11 | ferrandina
# Processing Record 22 of Set 11 | aleksandrov gay
# Processing Record 23 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 11 | manzhouli
# Processing Record 25 of Set 11 | suining
# Processing Record 26 of Set 11 | pemba
# Processing Record 27 of Set 11 | darhan
# Processing Record 28 of Set 11 | dali
# Processing Record 29 of Set 11 | turayf
# Processing Record 30 of Set 11 | skelleftea
# Processing Record 31 of Set 11 | mehamn
# Processing Record 32 of Set 11 | lubao
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | baranain
# Processing Record 35 of Set 11 | pokhara
# Processing Record 36 of Set 11 | denpasar
# Processing Record 37 of Set 11 | bemidji
# Processing Record 38 of Set 11 | necaxa
# Processing Record 39 of Set 11 | iranshahr
# Processing Record 40 of Set 11 | buluang
# Processing Record 41 of Set 11 | puerto quijarro
# Processing Record 42 of Set 11 | lazo
# Processing Record 43 of Set 11 | bairnsdale
# Processing Record 44 of Set 11 | coihaique
# Processing Record 45 of Set 11 | grindavik
# Processing Record 46 of Set 11 | itaituba
# Processing Record 47 of Set 11 | foca
# Processing Record 48 of Set 11 | fereydun kenar
# Processing Record 49 of Set 11 | verkhnevilyuysk
# Processing Record 50 of Set 11 | jinxiang
# Processing Record 1 of Set 12 | parabel
# Processing Record 2 of Set 12 | sheridan
# Processing Record 3 of Set 12 | trinidad
# Processing Record 4 of Set 12 | sao joao batista
# Processing Record 5 of Set 12 | half moon bay
# Processing Record 6 of Set 12 | carlos antonio lopez
# Processing Record 7 of Set 12 | bolkhov
# Processing Record 8 of Set 12 | waycross
# Processing Record 9 of Set 12 | adrar
# Processing Record 10 of Set 12 | kudahuvadhoo
# Processing Record 11 of Set 12 | klaksvik
# Processing Record 12 of Set 12 | puerto escondido
# Processing Record 13 of Set 12 | kasongo
# Processing Record 14 of Set 12 | bandar-e lengeh
# Processing Record 15 of Set 12 | santa fe
# Processing Record 16 of Set 12 | skaudvile
# Processing Record 17 of Set 12 | nampula
# Processing Record 18 of Set 12 | itarema
# Processing Record 19 of Set 12 | makakilo city
# Processing Record 20 of Set 12 | rio grande
# Processing Record 21 of Set 12 | inhambane
# Processing Record 22 of Set 12 | olavarria
# Processing Record 23 of Set 12 | camacha
# Processing Record 24 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 25 of Set 12 | batticaloa
# Processing Record 26 of Set 12 | yangjiang
# Processing Record 27 of Set 12 | edd
# Processing Record 28 of Set 12 | hansot
# Processing Record 29 of Set 12 | oksfjord
# Processing Record 30 of Set 12 | yumen
# Processing Record 31 of Set 12 | proletarskiy
# Processing Record 32 of Set 12 | amahai
# Processing Record 33 of Set 12 | sharqpur
# Processing Record 34 of Set 12 | villarrica
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | otane
# Processing Record 37 of Set 12 | presidencia roque saenz pena
# Processing Record 38 of Set 12 | yingshang
# City not found. Skipping...
# Processing Record 39 of Set 12 | warsaw
# Processing Record 40 of Set 12 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 41 of Set 12 | okahandja
# Processing Record 42 of Set 12 | saint-francois
# Processing Record 43 of Set 12 | shirokiy
# Processing Record 44 of Set 12 | young
# Processing Record 45 of Set 12 | alekseyevsk
# Processing Record 46 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 12 | boa vista
# Processing Record 49 of Set 12 | daru
# Processing Record 50 of Set 12 | bosaso
# Processing Record 1 of Set 13 | bay roberts
# Processing Record 2 of Set 13 | rafaela
# Processing Record 3 of Set 13 | haimen
# Processing Record 4 of Set 13 | sola
# Processing Record 5 of Set 13 | djibo
# Processing Record 6 of Set 13 | dunedin
# Processing Record 7 of Set 13 | el mante
# Processing Record 8 of Set 13 | springville
# Processing Record 9 of Set 13 | dubbo
# Processing Record 10 of Set 13 | verdun
# Processing Record 11 of Set 13 | riyadh
# Processing Record 12 of Set 13 | mount gambier
# Processing Record 13 of Set 13 | caala
# Processing Record 14 of Set 13 | bathsheba
# Processing Record 15 of Set 13 | lamar
# Processing Record 16 of Set 13 | ures
# Processing Record 17 of Set 13 | natal
# Processing Record 18 of Set 13 | pahrump
# Processing Record 19 of Set 13 | mastung
# Processing Record 20 of Set 13 | gisborne
# Processing Record 21 of Set 13 | marzuq
# Processing Record 22 of Set 13 | fez
# Processing Record 23 of Set 13 | athabasca
# Processing Record 24 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | yhu
# Processing Record 26 of Set 13 | victor harbor
# Processing Record 27 of Set 13 | sulphur springs
# Processing Record 28 of Set 13 | rawson
# Processing Record 29 of Set 13 | puerto de la cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Import pandas

import pandas as pd

# convert the array of dictionaries to a Pandas Dataframe

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Flinders -34.5833  150.8552     64.18        52          23       11.01
# 1   Ostrovnoy  68.0531   39.5131     22.66        94         100       15.84
# 2     Maumere  -8.6199  122.2111     80.80        77         100        3.33
# 3       Airai  -8.9266  125.4092     62.01        84          68        1.39
# 4       Rawah  34.4816   41.9093     58.96        62         100        7.78
# 5      Kodiak  57.7900 -152.4072     35.11        93         100        3.44
# 6    Karratha -20.7377  116.8463     80.26        37           4       11.54
# 7     Halifax  44.6453  -63.5724     32.00        67          75        6.91
# 8    Khandyga  62.6667  135.6000    -62.03       100          75        0.92
# 9  Punto Fijo  11.6956  -70.1996     80.10        78          92       24.81
#
#   Country                 Date
# 0      AU  2022-12-14 21:49:00
# 1      RU  2022-12-14 21:44:40
# 2      ID  2022-12-14 21:48:22
# 3      TL  2022-12-14 21:49:01
# 4      IQ  2022-12-14 21:49:01
# 5      US  2022-12-14 21:42:15
# 6      AU  2022-12-14 21:49:02
# 7      CA  2022-12-14 21:48:21
# 8      RU  2022-12-14 21:49:03
# 9      VE  2022-12-14 21:49:04

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                   City Country                 Date      Lat       Lng  \
# 0             Flinders      AU  2022-12-14 21:49:00 -34.5833  150.8552
# 1            Ostrovnoy      RU  2022-12-14 21:44:40  68.0531   39.5131
# 2              Maumere      ID  2022-12-14 21:48:22  -8.6199  122.2111
# 3                Airai      TL  2022-12-14 21:49:01  -8.9266  125.4092
# 4                Rawah      IQ  2022-12-14 21:49:01  34.4816   41.9093
# ..                 ...     ...                  ...      ...       ...
# 578                Yhu      PY  2022-12-14 22:04:49 -25.0500  -55.9167
# 579      Victor Harbor      AU  2022-12-14 22:04:49 -35.5667  138.6167
# 580    Sulphur Springs      US  2022-12-14 22:04:50  33.1385  -95.6011
# 581             Rawson      AR  2022-12-14 22:04:50 -43.3002  -65.1023
# 582  Puerto De La Cruz      ES  2022-12-14 22:03:25  28.4140  -16.5487
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0       64.18        52          23       11.01
# 1       22.66        94         100       15.84
# 2       80.80        77         100        3.33
# 3       62.01        84          68        1.39
# 4       58.96        62         100        7.78
# ..        ...       ...         ...         ...
# 578     75.96        53           0        3.24
# 579     57.99        73          92        1.01
# 580     55.54        43           0       12.66
# 581     63.54        47          60       14.43
# 582     70.03        81          24        4.00
#
# [583 rows x 9 columns]

# %%
# Create the output file (CSV).

output_data_file = "weather_data/cities.csv"

# Export the City_data into a CSV

city_data_df.to_csv(output_data_file, index_label="City_ID")
